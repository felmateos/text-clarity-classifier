# %%
#!pip install -r ../requirements.txt

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import random
import torch
from transformers import BertTokenizer, BertModel
import pandas as pd

# %%
seed = 777
random.seed(seed)

torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %%
import torch
 
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch

print(torch.cuda.is_available())
print(f"CUDA version: {torch.version.cuda}")

# Storing ID of current CUDA device
cuda_id = torch.cuda.current_device()
print(torch.cuda.current_device())
	
print(torch.cuda.get_device_name(cuda_id))
# Out:
# True
# CUDA version: 11.8
# 0
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
model_name = "neuralmind/bert-base-portuguese-cased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

# %%
df = pd.read_csv('../data/esic2023_cleaned.csv')

df.head()
# Out:
#    Unnamed: 0                                          resp_text clarity  \
# 0           0   Prezada Senhora, Informa-se que o DNIT é uma ...      c1
# 1           1   Prezada,   Os dados se referem somente aos na...      c1
# 2           2   Prezado Usuário, Inicialmente agradecemos o s...      c1
# 3           3   Prezada,   Referimo-nos a sua demanda, regist...      c1
# 4           4   Prezada,   Segue anexa a resposta da área com...      c1
#
#    Class                                             tokens  \
# 0      0  ['prezada', 'senhora', 'informase', 'que', 'o'...
# 1      0  ['prezada', 'os', 'dados', 'se', 'referem', 's...
# 2      0  ['prezado', 'usuário', 'inicialmente', 'agrade...
# 3      0  ['prezada', 'referimonos', 'a', 'sua', 'demand...
# 4      0  ['prezada', 'segue', 'anexa', 'a', 'resposta',...
#
#                                                lemma  \
# 0  prezar senhor informase que o dnit ser um auta...
# 1  prezar o dar se referir somente a o nascido vi...
# 2  prezar usuário inicialmente agradecer o seu co...
# 3  prezar referimono o seu demanda registrar em o...
# 4  prezar seguir anexo o resposta de o área compe...
#
#                                               ngram2  \
# 0  [('prezar', 'senhor'), ('senhor', 'informase')...
# 1  [('prezar', 'o'), ('o', 'dar'), ('dar', 'se'),...
# 2  [('prezar', 'usuário'), ('usuário', 'inicialme...
# 3  [('prezar', 'referimono'), ('referimono', 'o')...
# 4  [('prezar', 'seguir'), ('seguir', 'anexo'), ('...
#
#                                               ngram3
# 0  [('prezar', 'senhor', 'informase'), ('senhor',...
# 1  [('prezar', 'o', 'dar'), ('o', 'dar', 'se'), (...
# 2  [('prezar', 'usuário', 'inicialmente'), ('usuá...
# 3  [('prezar', 'referimono', 'o'), ('referimono',...
# 4  [('prezar', 'seguir', 'anexo'), ('seguir', 'an...

# %%
def get_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512, add_special_tokens = True).to(device)
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.sum(dim=1).squeeze().cpu().numpy()
    r = list(embeddings)
    return r

# %%
#df['bert_embeddings'] = df['resp_text'].apply(get_bert_embeddings)
#df.head()

# %%
embeddings = []
for text in df['resp_text']:
    embeddings.append(get_bert_embeddings(text))

# %%
labels = ['emb_' + str(i) for i in range(len(embeddings[0]))]

# %%
df_embeddings = pd.DataFrame(embeddings, columns=labels)

# %%
from sklearn.preprocessing import MinMaxScaler 
import numpy as np

# %%
from sklearn import preprocessing

x = df_embeddings.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_embeddings = pd.DataFrame(x_scaled)

# %%
df_embeddings.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.505127  0.766378  0.105300  0.285969  0.092293  0.249332  0.465746
# 1  0.469561  0.688681  0.113576  0.264515  0.116232  0.267609  0.468771
# 2  0.532808  0.769794  0.053227  0.283687  0.038090  0.184949  0.500581
# 3  0.351271  0.637699  0.287832  0.257460  0.198257  0.396646  0.468053
# 4  0.407822  0.682736  0.366654  0.400153  0.280517  0.355127  0.448908
#
#         7         8         9    ...       758       759       760       761  \
# 0  0.324952  0.691307  0.839414  ...  0.275737  0.716399  0.905849  0.889190
# 1  0.290847  0.706276  0.769807  ...  0.262989  0.694362  0.917148  0.832956
# 2  0.308323  0.679207  0.865095  ...  0.264708  0.726420  0.949025  0.940053
# 3  0.286730  0.582105  0.683174  ...  0.274973  0.694385  0.649727  0.706238
# 4  0.301572  0.707264  0.858857  ...  0.461279  0.629783  0.594298  0.649282
#
#         762       763       764       765       766       767
# 0  0.045048  0.879967  0.528071  0.093110  0.531860  0.877069
# 1  0.092697  0.904497  0.501777  0.160684  0.560638  0.876449
# 2  0.048876  0.917774  0.479433  0.100289  0.538197  0.934336
# 3  0.181229  0.676903  0.572161  0.224631  0.527368  0.727080
# 4  0.243664  0.698317  0.506059  0.309669  0.537712  0.584884
#
# [5 rows x 768 columns]

# %%
df_embeddings.shape
# Out:
# (6000, 768)

# %%
final = pd.concat([df, df_embeddings], axis=1)

# %%
final = final.iloc[:,1:]

# %%
final.iloc[0:3000]
# Out:
#                                               resp_text clarity  Class  \
# 0      Prezada Senhora, Informa-se que o DNIT é uma ...      c1      0
# 1      Prezada,   Os dados se referem somente aos na...      c1      0
# 2      Prezado Usuário, Inicialmente agradecemos o s...      c1      0
# 3      Prezada,   Referimo-nos a sua demanda, regist...      c1      0
# 4      Prezada,   Segue anexa a resposta da área com...      c1      0
# ...                                                 ...     ...    ...
# 2995   Prezada, O organizador é o Centro de Seleção ...    c234      1
# 2996   Prezada, os dados estão disponíveis na Plataf...    c234      1
# 2997   Prezada, pedimos desculpas pela demora...  A ...    c234      1
# 2998   O Serviço de Informações ao Cidadão (SIC) da ...    c234      1
# 2999   Olá Edson, bom dia! Recebemos seu pedido de i...    c234      1
#
#                                                  tokens  \
# 0     ['prezada', 'senhora', 'informase', 'que', 'o'...
# 1     ['prezada', 'os', 'dados', 'se', 'referem', 's...
# 2     ['prezado', 'usuário', 'inicialmente', 'agrade...
# 3     ['prezada', 'referimonos', 'a', 'sua', 'demand...
# 4     ['prezada', 'segue', 'anexa', 'a', 'resposta',...
# ...                                                 ...
# 2995  ['prezada', 'o', 'organizador', 'é', 'o', 'cen...
# 2996  ['prezada', 'os', 'dados', 'estão', 'disponíve...
# 2997  ['prezada', 'pedimos', 'desculpas', 'pela', 'd...
# 2998  ['o', 'serviço', 'de', 'informações', 'ao', 'c...
# 2999  ['olá', 'edson', 'bom', 'dia', 'recebemos', 's...
#
#                                                   lemma  \
# 0     prezar senhor informase que o dnit ser um auta...
# 1     prezar o dar se referir somente a o nascido vi...
# 2     prezar usuário inicialmente agradecer o seu co...
# 3     prezar referimono o seu demanda registrar em o...
# 4     prezar seguir anexo o resposta de o área compe...
# ...                                                 ...
# 2995  prezar o organizador ser o centro de seleção d...
# 2996  prezar o dar estar disponívil em o plataforma ...
# 2997  prezar pedimos desculpa por o demor o nomencla...
# 2998  o serviço de informação a o cidadão sic de o a...
# 2999  olá edson bom dia receb seu pedir de informaçã...
#
#                                                  ngram2  \
# 0     [('prezar', 'senhor'), ('senhor', 'informase')...
# 1     [('prezar', 'o'), ('o', 'dar'), ('dar', 'se'),...
# 2     [('prezar', 'usuário'), ('usuário', 'inicialme...
# 3     [('prezar', 'referimono'), ('referimono', 'o')...
# 4     [('prezar', 'seguir'), ('seguir', 'anexo'), ('...
# ...                                                 ...
# 2995  [('prezar', 'o'), ('o', 'organizador'), ('orga...
# 2996  [('prezar', 'o'), ('o', 'dar'), ('dar', 'estar...
# 2997  [('prezar', 'pedimos'), ('pedimos', 'desculpa'...
# 2998  [('o', 'serviço'), ('serviço', 'de'), ('de', '...
# 2999  [('olá', 'edson'), ('edson', 'bom'), ('bom', '...
#
#                                                  ngram3         0         1  \
# 0     [('prezar', 'senhor', 'informase'), ('senhor',...  0.505127  0.766378
# 1     [('prezar', 'o', 'dar'), ('o', 'dar', 'se'), (...  0.469561  0.688681
# 2     [('prezar', 'usuário', 'inicialmente'), ('usuá...  0.532808  0.769794
# 3     [('prezar', 'referimono', 'o'), ('referimono',...  0.351271  0.637699
# 4     [('prezar', 'seguir', 'anexo'), ('seguir', 'an...  0.407822  0.682736
# ...                                                 ...       ...       ...
# 2995  [('prezar', 'o', 'organizador'), ('o', 'organi...  0.530569  0.774251
# 2996  [('prezar', 'o', 'dar'), ('o', 'dar', 'estar')...  0.505773  0.757485
# 2997  [('prezar', 'pedimos', 'desculpa'), ('pedimos'...  0.498600  0.829107
# 2998  [('o', 'serviço', 'de'), ('serviço', 'de', 'in...  0.185752  0.593819
# 2999  [('olá', 'edson', 'bom'), ('edson', 'bom', 'di...  0.494674  0.607722
#
#              2  ...       758       759       760       761       762  \
# 0     0.105300  ...  0.275737  0.716399  0.905849  0.889190  0.045048
# 1     0.113576  ...  0.262989  0.694362  0.917148  0.832956  0.092697
# 2     0.053227  ...  0.264708  0.726420  0.949025  0.940053  0.048876
# 3     0.287832  ...  0.274973  0.694385  0.649727  0.706238  0.181229
# 4     0.366654  ...  0.461279  0.629783  0.594298  0.649282  0.243664
# ...        ...  ...       ...       ...       ...       ...       ...
# 2995  0.071944  ...  0.266448  0.734691  0.925980  0.882472  0.092065
# 2996  0.078151  ...  0.271834  0.697474  0.941125  0.917829  0.089754
# 2997  0.183060  ...  0.284812  0.732802  0.866494  0.838716  0.168953
# 2998  0.419010  ...  0.391033  0.534651  0.462995  0.513996  0.315993
# 2999  0.248245  ...  0.351014  0.691503  0.715695  0.758641  0.153948
#
#            763       764       765       766       767
# 0     0.879967  0.528071  0.093110  0.531860  0.877069
# 1     0.904497  0.501777  0.160684  0.560638  0.876449
# 2     0.917774  0.479433  0.100289  0.538197  0.934336
# 3     0.676903  0.572161  0.224631  0.527368  0.727080
# 4     0.698317  0.506059  0.309669  0.537712  0.584884
# ...        ...       ...       ...       ...       ...
# 2995  0.895249  0.543895  0.089107  0.523779  0.891611
# 2996  0.931985  0.514931  0.142427  0.555219  0.890816
# 2997  0.825449  0.566021  0.164663  0.512016  0.919914
# 2998  0.554416  0.705462  0.325962  0.527642  0.486246
# 2999  0.732952  0.543797  0.140891  0.567605  0.722196
#
# [3000 rows x 775 columns]

# %%
final.head()
# Out:
#                                            resp_text clarity  Class  \
# 0   Prezada Senhora, Informa-se que o DNIT é uma ...      c1      0
# 1   Prezada,   Os dados se referem somente aos na...      c1      0
# 2   Prezado Usuário, Inicialmente agradecemos o s...      c1      0
# 3   Prezada,   Referimo-nos a sua demanda, regist...      c1      0
# 4   Prezada,   Segue anexa a resposta da área com...      c1      0
#
#                                               tokens  \
# 0  ['prezada', 'senhora', 'informase', 'que', 'o'...
# 1  ['prezada', 'os', 'dados', 'se', 'referem', 's...
# 2  ['prezado', 'usuário', 'inicialmente', 'agrade...
# 3  ['prezada', 'referimonos', 'a', 'sua', 'demand...
# 4  ['prezada', 'segue', 'anexa', 'a', 'resposta',...
#
#                                                lemma  \
# 0  prezar senhor informase que o dnit ser um auta...
# 1  prezar o dar se referir somente a o nascido vi...
# 2  prezar usuário inicialmente agradecer o seu co...
# 3  prezar referimono o seu demanda registrar em o...
# 4  prezar seguir anexo o resposta de o área compe...
#
#                                               ngram2  \
# 0  [('prezar', 'senhor'), ('senhor', 'informase')...
# 1  [('prezar', 'o'), ('o', 'dar'), ('dar', 'se'),...
# 2  [('prezar', 'usuário'), ('usuário', 'inicialme...
# 3  [('prezar', 'referimono'), ('referimono', 'o')...
# 4  [('prezar', 'seguir'), ('seguir', 'anexo'), ('...
#
#                                               ngram3         0         1  \
# 0  [('prezar', 'senhor', 'informase'), ('senhor',...  0.505127  0.766378
# 1  [('prezar', 'o', 'dar'), ('o', 'dar', 'se'), (...  0.469561  0.688681
# 2  [('prezar', 'usuário', 'inicialmente'), ('usuá...  0.532808  0.769794
# 3  [('prezar', 'referimono', 'o'), ('referimono',...  0.351271  0.637699
# 4  [('prezar', 'seguir', 'anexo'), ('seguir', 'an...  0.407822  0.682736
#
#           2  ...       758       759       760       761       762       763  \
# 0  0.105300  ...  0.275737  0.716399  0.905849  0.889190  0.045048  0.879967
# 1  0.113576  ...  0.262989  0.694362  0.917148  0.832956  0.092697  0.904497
# 2  0.053227  ...  0.264708  0.726420  0.949025  0.940053  0.048876  0.917774
# 3  0.287832  ...  0.274973  0.694385  0.649727  0.706238  0.181229  0.676903
# 4  0.366654  ...  0.461279  0.629783  0.594298  0.649282  0.243664  0.698317
#
#         764       765       766       767
# 0  0.528071  0.093110  0.531860  0.877069
# 1  0.501777  0.160684  0.560638  0.876449
# 2  0.479433  0.100289  0.538197  0.934336
# 3  0.572161  0.224631  0.527368  0.727080
# 4  0.506059  0.309669  0.537712  0.584884
#
# [5 rows x 775 columns]

# %%
final.isnull().sum().sum()
# Out:
# 0

# %%
f1 = final.iloc[0:3000]
f2 = final.iloc[3000:]

# %%
f1.to_csv('../emebeddings/BERT_Embeddings_1.csv', index=False)
f2.to_csv('../emebeddings/BERT_Embeddings_2.csv', index=False)

# %%
final.head()
# Out:
#                                            resp_text clarity  Class  \
# 0   Prezada Senhora, Informa-se que o DNIT é uma ...      c1      0
# 1   Prezada,   Os dados se referem somente aos na...      c1      0
# 2   Prezado Usuário, Inicialmente agradecemos o s...      c1      0
# 3   Prezada,   Referimo-nos a sua demanda, regist...      c1      0
# 4   Prezada,   Segue anexa a resposta da área com...      c1      0
#
#                                               tokens  \
# 0  ['prezada', 'senhora', 'informase', 'que', 'o'...
# 1  ['prezada', 'os', 'dados', 'se', 'referem', 's...
# 2  ['prezado', 'usuário', 'inicialmente', 'agrade...
# 3  ['prezada', 'referimonos', 'a', 'sua', 'demand...
# 4  ['prezada', 'segue', 'anexa', 'a', 'resposta',...
#
#                                                lemma  \
# 0  prezar senhor informase que o dnit ser um auta...
# 1  prezar o dar se referir somente a o nascido vi...
# 2  prezar usuário inicialmente agradecer o seu co...
# 3  prezar referimono o seu demanda registrar em o...
# 4  prezar seguir anexo o resposta de o área compe...
#
#                                               ngram2  \
# 0  [('prezar', 'senhor'), ('senhor', 'informase')...
# 1  [('prezar', 'o'), ('o', 'dar'), ('dar', 'se'),...
# 2  [('prezar', 'usuário'), ('usuário', 'inicialme...
# 3  [('prezar', 'referimono'), ('referimono', 'o')...
# 4  [('prezar', 'seguir'), ('seguir', 'anexo'), ('...
#
#                                               ngram3         0         1  \
# 0  [('prezar', 'senhor', 'informase'), ('senhor',...  0.505127  0.766378
# 1  [('prezar', 'o', 'dar'), ('o', 'dar', 'se'), (...  0.469561  0.688681
# 2  [('prezar', 'usuário', 'inicialmente'), ('usuá...  0.532808  0.769794
# 3  [('prezar', 'referimono', 'o'), ('referimono',...  0.351271  0.637699
# 4  [('prezar', 'seguir', 'anexo'), ('seguir', 'an...  0.407822  0.682736
#
#           2  ...       758       759       760       761       762       763  \
# 0  0.105300  ...  0.275737  0.716399  0.905849  0.889190  0.045048  0.879967
# 1  0.113576  ...  0.262989  0.694362  0.917148  0.832956  0.092697  0.904497
# 2  0.053227  ...  0.264708  0.726420  0.949025  0.940053  0.048876  0.917774
# 3  0.287832  ...  0.274973  0.694385  0.649727  0.706238  0.181229  0.676903
# 4  0.366654  ...  0.461279  0.629783  0.594298  0.649282  0.243664  0.698317
#
#         764       765       766       767
# 0  0.528071  0.093110  0.531860  0.877069
# 1  0.501777  0.160684  0.560638  0.876449
# 2  0.479433  0.100289  0.538197  0.934336
# 3  0.572161  0.224631  0.527368  0.727080
# 4  0.506059  0.309669  0.537712  0.584884
#
# [5 rows x 775 columns]
